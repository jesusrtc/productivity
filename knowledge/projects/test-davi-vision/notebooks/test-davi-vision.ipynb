# %% [markdown]
# # Investigation: test-davi-vision
#
# Auto-generated audit trail via `davi_runner.py`.
#
# Created: 2026-04-21 13:17

# %%
# [2026-04-21 13:17:07]
# !pip install lipy-davi
# Out:
# Looking in indexes: https://lerna.tools.corp.linkedin.com/pypi/simple, https://artifactory.corp.linkedin.com:8083/artifactory/api/pypi/pypi-external/simple, https://artifactory.corp.linkedin.com:8083/artifactory/api/pypi/pypi-internal/simple
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# [2026-04-21 13:17:26]

from linkedin.davi import setup, plot
import pandas as pd
import numpy as np
import plotly.express as px

import linkedin.darwinfilemanager
open("darwin://lipy_trustim/ir/ir.py")
from lipy_trustim.ir.ir import pivot

get_ipython().run_line_magic("reload_ext", "linkedin.lisql")
get_ipython().run_line_magic("config", "SqlMagic.autocommit=False")
get_ipython().run_line_magic("manage_trino", "Holdem")
get_ipython().run_line_magic("set_proxyUser", "trustim")
print("setup OK")
# Out:
# GAI proxy is already running
# Will connect to holdem...
# trino://<user>@trino-holdem.prod.linkedin.com:443/hive
# Trino Query url - https://trino-holdem.prod.linkedin.com/ui/query.html?20260421_201724_14465_i3drn
# Query execution completed. Fetched 1 rows.
# Proxy user for current presto session is set to trustim.
# All setup!
# Will connect to Holdem...
# trino://<user>@trino-holdem.prod.linkedin.com:443/hive
# Trino Query url - https://trino-holdem.prod.linkedin.com/ui/query.html?20260421_201725_37097_42u3c
# Query execution completed. Fetched 1 rows.
# Proxy user for current presto session is set to trustim.
# setup OK
# <script>
#   (function () {
#       /* ---------- create modal -------------------------------- */
#       var modal = document.getElementById('davi-search-modal');
#       if (!modal) {
#           modal = document.createElement('div');
#           modal.id = 'davi-search-modal';
#           modal.style.cssText =
# ...

# %%
# [2026-04-21 14:08:39]
from linkedin.davi import plot
import pandas as pd

d = pd.DataFrame({
    'day': pd.date_range('2026-04-01', periods=7),
    'registrations': [100, 120, 95, 140, 150, 130, 125],
})

plot(d, x='day', y='registrations', title='Smoke test — 7-day trend')

print(f"total={d['registrations'].sum()}")
print(f"mean={d['registrations'].mean():.1f}")
# Out:
# LOG: Executing DAVI MagicPlotService start=2026-04-21T21:08:36.351070+00:00 end=2026-04-21T21:08:36.397848+00:00 status=SUCCESS
# LOG: Executing DAVI MagicPlotWidget start=2026-04-21T21:08:36.351023+00:00 end=2026-04-21T21:08:37.687548+00:00 status=SUCCESS
# total=860
# mean=122.9
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>registrations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2026-04-01</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2026-04-02</td>
#       <td>120</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2026-04-03</td>
# ...
